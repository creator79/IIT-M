# %% [markdown]
# # Day 3 ? Assignment 2: Linear Algebra in Machine Learning MCQs
#
# All supplied questions are answered below.

# %% [markdown]
# ## Answer key\n\n1. Answer: B\n2. Answer: C\n3. Answer: B\n4. Answer: B\n5. Answer: C\n6. Answer: A\n7. Answer: B\n8. Answer: B\n9. Answer: B\n10. Answer: B\n11. Answer: B\n12. Answer: A\n13. Answer: B\n14. Answer: B\n15. Answer: B\n16. Answer: B\n17. Answer: B\n18. Answer: B\n19. Answer: B\n20. Answer: B\n21. Answer: B\n22. Answer: A\n23. Answer: B\n24. Answer: B\n25. Answer: B\n26. Answer: B\n27. Answer: B\n28. Answer: B\n29. Answer: B\n30. Answer: B\n31. Answer: B\n32. Answer: A\n33. Answer: A\n34. Answer: A\n35. Answer: A\n36. Answer: B\n37. Answer: A\n38. Answer: B\n39. Answer: B\n40. Answer: B\n41. Answer: B\n42. Answer: A\n43. Answer: B\n44. Answer: B\n45. Answer: B\n46. Answer: B\n47. Answer: B\n48. Answer: B\n49. Answer: C\n50. Answer: A
