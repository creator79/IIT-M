# %% [markdown]
# # Day 3 ? Assignment 4: Dictionary Basics
#
# All supplied questions are answered below.

# %%
# Questions 1?35: creation, access, updates, deletion, methods, and comprehensions
student = {'Name':'John','Age':21,'Department':'CSE'}
print('Q1 dictionary: key-value mapping'); print('Q2:', student); print('Q3:', student['Age'])
print('Q4 missing key raises KeyError; use get for a safe lookup:', student.get('Marks'))
print('Q5 [] raises KeyError, get() returns None/default.'); print('Q6 keys:', list(student.keys())); print('Q7 values:', list(student.values()))
print('Q8:', *[f'{k} : {v}' for k,v in student.items()], sep='\n'); print('Q9:', 'Age' in student); print('Q10:', len(student))
student['City']='Chennai'; student['Age']=22; print('Q11?12:',student); del student['Department']; print('Q13:',student); print('Q14:',student.popitem()); student.clear(); print('Q15:',student)
keys=['A','B','C']; values=[10,20,30]; d=dict(zip(keys,values)); print('Q16:',d); print('Q17:', d|{'D':40}); print('Q18:',d.copy())
marks={'A':85,'B':92,'C':76}; print('Q19?20:',max(marks.values()), max(marks,key=marks.get),'scored',max(marks.values()))
print('Q21:',marks.keys()); print('Q22:',marks.values()); print('Q23:',marks.items()); print('Q24:',sum(v>50 for v in marks.values())); print('Q25:',{k:v for k,v in marks.items() if v>80}); print('Q26:',sum(marks.values())/len(marks)); print('Q27:',sum(k.startswith('A') for k in marks))
print('Q28?35: keys(), values(), items(), pop(), popitem(), update(), setdefault(), and fromkeys() manage dictionary content.')
print('fromkeys:',dict.fromkeys(['A','B'],0))

# %%
# Questions 36?45
text='banana'; frequency={c:text.count(c) for c in set(text)}; print('Q36:',frequency)
sentence='I love Python and I love AI'.split(); print('Q37:',{word:sentence.count(word) for word in dict.fromkeys(sentence)})
print('Q38:',{v:k for k,v in {'A':1,'B':2}.items()}); values={'A':1,'B':2,'C':1}; print('Q39:',{v for v in values.values() if list(values.values()).count(v)>1})
print('Q40:',dict(sorted(values.items()))); print('Q41:',dict(sorted(values.items(),key=lambda item:item[1])))
print('Q42:',{n:n*n for n in range(1,6)}); print('Q43:',{n:n**3 for n in range(1,11)}); print('Q44:',{k:v for k,v in zip(keys,[10,20,30])})
print('Q45:',{n:'Even' if n%2==0 else 'Odd' for n in range(1,21)})

# %%
# Questions 46?55: nested students and practical dictionaries
students={101:{'Name':'John','Age':20},102:{'Name':'Alice','Age':21},103:{'Name':'Peter','Age':22}}
print('Q46:',students); print('Q47:',students[102]); students[101]['Age']=21; print('Q48:',students[101]);
for item in students.values(): item['Marks']=80
print('Q49?50:',students)
sales={'Jan':2500,'Feb':3000,'Mar':2700,'Apr':4000}; print('Q51:',max(sales,key=sales.get))
print('Q52:',{w:len(w) for w in 'Python is amazing'.split()}); inventory={'Pen':25,'Pencil':50,'Eraser':15}; print('Q53:',{k:v-5 for k,v in inventory.items()})
d1={'A':10,'B':20};d2={'B':15,'C':5};print('Q54:',{k:d1.get(k,0)+d2.get(k,0) for k in d1.keys()|d2.keys()})
# Q55 functions for a phonebook
phonebook={}
def add(name,number): phonebook[name]=number
def search(name): return phonebook.get(name,'Contact not found')
def update(name,number): phonebook[name]=number
def delete(name): return phonebook.pop(name,'Contact not found')
add('John','9876543210'); update('John','9999999999'); print('Q55:',phonebook,search('John'),delete('John'))
