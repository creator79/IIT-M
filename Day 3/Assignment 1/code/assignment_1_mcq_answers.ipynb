# %% [markdown]
# # Day 3 ? Assignment 1: Linear Algebra MCQs
#
# All supplied questions are answered below.

# %% [markdown]
# ## Answer key\n\n1. Answer: B\n2. Answer: C\n3. Answer: B\n4. Answer: B\n5. Answer: B\n6. Answer: C\n7. Answer: B\n8. Answer: A\n9. Answer: B\n10. Answer: B\n11. Answer: C\n12. Answer: B\n13. Answer: B\n14. Answer: B\n15. Answer: C\n16. Answer: B\n17. Answer: D\n18. Answer: B\n19. Answer: B\n20. Answer: C\n21. Answer: C\n22. Answer: B\n23. Answer: B\n24. Answer: B\n25. Answer: C\n26. Answer: C\n27. Answer: B\n28. Answer: B\n29. Answer: B\n30. Answer: B\n31. Answer: B\n32. Answer: A\n33. Answer: B\n34. Answer: B\n35. Answer: B\n36. Answer: B\n37. Answer: A\n38. Answer: B\n39. Answer: B\n40. Answer: B\n41. Answer: B\n42. Answer: A\n43. Answer: B\n44. Answer: B\n45. Answer: B\n46. Answer: B\n47. Answer: B\n48. Answer: B\n49. Answer: B\n50. Answer: C
